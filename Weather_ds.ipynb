# %% [markdown]
# # Weather Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('1. Weather Data.csv')

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# <h4>find all the unique 'windspeed' values in the data

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# <h4>find the number of times when the 'weather' is exactly clear

# %%
df['Weather'].value_counts()['Clear']
# Out:
# 1326

# %%
df[df['Weather']=='Clear'].head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear

# %%
df.groupby('Weather').get_group('Clear').head(2)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear

# %% [markdown]
# <h4>find the number of times when the 'wind speed' was exactly 4 km/h

# %%
df[df['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
df[df['Wind Speed_km/h']==4].count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %% [markdown]
# <h4>find out all the null values in the data

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# <h4>Rename the column name 'weather' of the df to 'weather_condition'

# %%
df.rename(columns={'Weather':'Weather_Condition'},inplace=True)

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# <h4>what is the mean visibility

# %%
df['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# <h4>what is the std of 'pressure' in this data

# %%
df['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# <h4>what is the variance of 'relative humidity' in this data

# %%
df['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %% [markdown]
# <h4>find all the instances when 'snow' was recorded.

# %%
df[df['Weather_Condition']=='Snow'].count()
# Out:
# Date/Time            390
# Temp_C               390
# Dew Point Temp_C     390
# Rel Hum_%            390
# Wind Speed_km/h      390
# Visibility_km        390
# Press_kPa            390
# Weather_Condition    390
# dtype: int64

# %%
df['Weather_Condition'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df['Weather_Condition']=='Snow']
df[df['Weather_Condition'].str.contains('Snow')].count()
# Out:
# Date/Time            583
# Temp_C               583
# Dew Point Temp_C     583
# Rel Hum_%            583
# Wind Speed_km/h      583
# Visibility_km        583
# Press_kPa            583
# Weather_Condition    583
# dtype: int64

# %% [markdown]
# <h4>find all instance when 'wind speed' is above 24 & 'visibility is 25

# %%
df[(df['Wind Speed_km/h']>24) & (df['Visibility_km']==25)].head(4)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0         79               30
# 24   1/2/2012 0:00     5.2               1.5         77               35
# 25   1/2/2012 1:00     4.6               0.0         72               39
# 26   1/2/2012 2:00     3.9              -0.9         71               32
#
#     Visibility_km  Press_kPa Weather_Condition
# 23           25.0      99.31            Cloudy
# 24           25.0      99.26      Rain Showers
# 25           25.0      99.26            Cloudy
# 26           25.0      99.26     Mostly Cloudy

# %% [markdown]
# what is the mean value of each column against each 'Weather_condition'

# %%
df.groupby('Weather_Condition').mean().head(5)
# Out:
#                            Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_Condition
# Clear                    6.825716          0.089367  64.497738
# Cloudy                   7.970544          2.375810  69.592593
# Drizzle                  7.353659          5.504878  88.243902
# Drizzle,Fog              8.067500          7.033750  93.275000
# Drizzle,Ice Pellets,Fog  0.400000         -0.700000  92.000000
#
#                          Wind Speed_km/h  Visibility_km   Press_kPa
# Weather_Condition
# Clear                          10.557315      30.153243  101.587443
# Cloudy                         16.127315      26.625752  100.911441
# Drizzle                        16.097561      17.931707  100.435366
# Drizzle,Fog                    11.862500       5.257500  100.786625
# Drizzle,Ice Pellets,Fog        20.000000       4.000000  100.790000

# %% [markdown]
# what is the min() & max() value of each column against each 'Weather_condition'

# %%
df.groupby('Weather_Condition').min().head()
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_Condition
# Clear                     1/11/2012 1:00   -23.3             -28.5         20
# Cloudy                    1/1/2012 17:00   -21.4             -26.8         18
# Drizzle                  1/23/2012 21:00     1.1              -0.2         74
# Drizzle,Fog              1/23/2012 20:00     0.0              -1.6         85
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather_Condition
# Clear                                  0           11.3      99.52
# Cloudy                                 0           11.3      98.39
# Drizzle                                0            6.4      97.84
# Drizzle,Fog                            0            1.0      98.65
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %%
df.groupby('Weather_Condition').max().head()
# Out:
#                                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather_Condition
# Clear                      9/9/2012 5:00    32.8              20.4         99
# Cloudy                    9/9/2012 23:00    30.5              22.6         99
# Drizzle                   9/30/2012 3:00    18.8              17.7         96
# Drizzle,Fog               9/30/2012 2:00    19.9              19.1        100
# Drizzle,Ice Pellets,Fog  12/17/2012 9:00     0.4              -0.7         92
#
#                          Wind Speed_km/h  Visibility_km  Press_kPa
# Weather_Condition
# Clear                                 33           48.3     103.63
# Cloudy                                54           48.3     103.65
# Drizzle                               30           25.0     101.56
# Drizzle,Fog                           28            9.7     102.07
# Drizzle,Ice Pellets,Fog               20            4.0     100.79

# %% [markdown]
# Show all the records where weather condition is fog

# %%
df[df['Weather_Condition']=='Fog'].count()
# Out:
# Date/Time            150
# Temp_C               150
# Dew Point Temp_C     150
# Rel Hum_%            150
# Wind Speed_km/h      150
# Visibility_km        150
# Press_kPa            150
# Weather_Condition    150
# dtype: int64

# %% [markdown]
# find all instance when 'weather is clear' or 'visibility' is above 40

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
df[(df['Weather_Condition']=='Clear')| (df['Visibility_km']>40)].head(5)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
#
#      Visibility_km  Press_kPa Weather_Condition
# 67            25.0     101.74             Clear
# 106           48.3     100.45      Mainly Clear
# 107           48.3     100.41      Mainly Clear
# 108           48.3     100.38      Mainly Clear
# 109           48.3     100.40      Mainly Clear

# %%
df[(df['Weather_Condition']=='Clear')| (df['Visibility_km']>40)].count()
# Out:
# Date/Time            3027
# Temp_C               3027
# Dew Point Temp_C     3027
# Rel Hum_%            3027
# Wind Speed_km/h      3027
# Visibility_km        3027
# Press_kPa            3027
# Weather_Condition    3027
# dtype: int64

# %% [markdown]
# 1)find all instance when 'weather is clear' & 'relative_humidity' is greater than 50 2) or 'Visibility' is above 40

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather_Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
# if the condition is not clear visibility gerater then 40 i.e mainly & mostly clear 
# if condition is clear visibility less than 40 
df[(df['Weather_Condition']=='Clear') & (df['Rel Hum_%']>50) | (df['Visibility_km']>40)].head(15)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
# 108  1/5/2012 12:00    -4.7              -9.6         69               20
# 109  1/5/2012 13:00    -4.4              -9.7         66               26
# 110  1/5/2012 14:00    -5.1             -10.7         65               22
# 111  1/5/2012 15:00    -4.3             -12.0         55               26
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
# 183  1/8/2012 15:00    -6.6             -12.9         61               20
# 241  1/11/2012 1:00   -10.7             -17.8         56               17
# ...
